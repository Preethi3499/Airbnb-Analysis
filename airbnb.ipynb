# %%
import pandas as pd
import pymongo

# %%
conn=pymongo.MongoClient("mongodb://pree3499:pree3499@ac-cmvu7ao-shard-00-00.y4puatd.mongodb.net:27017,ac-cmvu7ao-shard-00-01.y4puatd.mongodb.net:27017,ac-cmvu7ao-shard-00-02.y4puatd.mongodb.net:27017/?ssl=true&replicaSet=atlas-hj325v-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")
db = conn.sample_airbnb
col = db.listingsAndReviews

# %%
# Query MongoDB collection and convert data to list of dictionaries
data_from_mongodb = col.find()

# %%
data_list=list(data_from_mongodb)

# %%
# Convert list of dictionaries to DataFrame
df = pd.DataFrame(data_list)

# %%
df
# Out:
#            _id                            listing_url  \
# 0     10059872  https://www.airbnb.com/rooms/10059872
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10069642  https://www.airbnb.com/rooms/10069642
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10066928  https://www.airbnb.com/rooms/10066928
# ...        ...                                    ...
# 5550   9993190   https://www.airbnb.com/rooms/9993190
# 5551   9887054   https://www.airbnb.com/rooms/9887054
# 5552   9937100   https://www.airbnb.com/rooms/9937100
# 5553   9908871   https://www.airbnb.com/rooms/9908871
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                    Soho Cozy, Spacious and Convenient
# 1                               Ribeira Charming Duplex
# 2                    Ótimo Apto proximo Parque Olimpico
# 3                              Private Room in Bushwick
# 4                        3 chambres au coeur du Plateau
# ...                                                 ...
# 5550  Just Steps from the Ocean at Premier Platinum ...
# 5551                Quarry Bay fully furnished studio C
# 5552                Frida's Centric&Stylish Studio Apt.
# 5553                        Family friendly beach house
# 5554                        Alugo Apartamento na Tijuca
#
#                                                 summary  \
# 0     Clean, fully furnish, Spacious 1 bedroom flat ...
# 1     Fantastic duplex apartment with three bedrooms...
# 2     Apartamento próximo ao centro dos Jogos Olímpi...
# 3     Here exists a very cozy room for rent in a sha...
# 4     Notre appartement comporte 3 chambres avec cha...
# ...                                                 ...
# 5550  Relax Hawaiian Style in Gated Community on Oce...
# 5551   Newly renovated studio flat with full furniture.
# 5552  Unique loft apartment with a Frida Kahlo decor...
# 5553  Only 400 metres to the beach,2 x carparks,clos...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                                   space  \
# 0
# 1     Privileged views of the Douro River and Ribeir...
# 2
# 3
# 4     Notre logement est lumineux, plein de vie et c...
# ...                                                 ...
# 5550  ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WI...
# 5551
# 5552  If you want to feel like a local in a charming...
# 5553
# 5554
#
#                                             description  \
# 0     Clean, fully furnish, Spacious 1 bedroom flat ...
# 1     Fantastic duplex apartment with three bedrooms...
# 2     Apartamento próximo ao centro dos Jogos Olímpi...
# 3     Here exists a very cozy room for rent in a sha...
# 4     Notre appartement comporte 3 chambres avec cha...
# ...                                                 ...
# 5550  Relax Hawaiian Style in Gated Community on Oce...
# 5551   Newly renovated studio flat with full furniture.
# 5552  Unique loft apartment with a Frida Kahlo decor...
# 5553  Only 400 metres to the beach,2 x carparks,clos...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                   neighborhood_overview  \
# 0
# 1     In the neighborhood of the river, you can find...
# 2
# 3
# 4     L'appartement se situe au coeur du Plateau, do...
# ...                                                 ...
# 5550  Location: Located at the south end of Lahaina ...
# 5551
# 5552  One minute walking from Catalonia Square, that...
# 5553
# 5554
#
#                                                   notes  \
# 0
# 1     Lose yourself in the narrow streets and stairc...
# 2
# 3
# 4
# ...                                                 ...
# 5550  Puamana Resort requires a $10/day resort fee w...
# 5551
# 5552  All the supplies are included in the price up ...
# 5553
# 5554
#
#                                                 transit  \
# 0
# 1     Transport: • Metro station and S. Bento railwa...
# 2
# 3
# 4     L'appartement se situe à égale distance des mé...
# ...                                                 ...
# 5550  You can walk to most attractions within Lahain...
# 5551
# 5552
# 5553
# 5554
#
#                                                  access  ...  \
# 0                                                        ...
# 1     We are always available to help guests. The ho...  ...
# 2                                                        ...
# 3                                                        ...
# 4     Le logement sera disponible en entier pour vot...  ...
# ...                                                 ...  ...
# 5550  Guests will have access to the 3 pools in the ...  ...
# 5551                                                     ...
# 5552  The weekly cleaning (with changing linens and ...  ...
# 5553                                                     ...
# 5554                                                     ...
#
#                                                  images  \
# 0     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# ...                                                 ...
# 5550  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5551  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5552  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5553  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5554  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                    host  \
# 0     {'host_id': '51624384', 'host_url': 'https://w...
# 1     {'host_id': '51399391', 'host_url': 'https://w...
# 2     {'host_id': '51670240', 'host_url': 'https://w...
# 3     {'host_id': '11275734', 'host_url': 'https://w...
# 4     {'host_id': '9036477', 'host_url': 'https://ww...
# ...                                                 ...
# 5550  {'host_id': '51013381', 'host_url': 'https://w...
# 5551  {'host_id': '31386255', 'host_url': 'https://w...
# 5552  {'host_id': '3479346', 'host_url': 'https://ww...
# 5553  {'host_id': '20914019', 'host_url': 'https://w...
# 5554  {'host_id': '47092481', 'host_url': 'https://w...
#
#                                                 address  \
# 0     {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 1     {'street': 'Porto, Porto, Portugal', 'suburb':...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'Brooklyn, NY, United States', 'sub...
# 4     {'street': 'Montréal, Québec, Canada', 'suburb...
# ...                                                 ...
# 5550  {'street': 'Lahaina, HI, United States', 'subu...
# 5551  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5552  {'street': 'Barcelona, Catalunya, Spain', 'sub...
# 5553  {'street': 'North Bondi, NSW, Australia', 'sub...
# 5554  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
#
#                                            availability  \
# 0     {'availability_30': 0, 'availability_60': 0, '...
# 1     {'availability_30': 28, 'availability_60': 47,...
# 2     {'availability_30': 0, 'availability_60': 0, '...
# 3     {'availability_30': 0, 'availability_60': 0, '...
# 4     {'availability_30': 0, 'availability_60': 0, '...
# ...                                                 ...
# 5550  {'availability_30': 0, 'availability_60': 8, '...
# 5551  {'availability_30': 18, 'availability_60': 48,...
# 5552  {'availability_30': 2, 'availability_60': 32, ...
# 5553  {'availability_30': 0, 'availability_60': 0, '...
# 5554  {'availability_30': 0, 'availability_60': 0, '...
#
#                                           review_scores  \
# 0     {'review_scores_accuracy': 10, 'review_scores_...
# 1     {'review_scores_accuracy': 9, 'review_scores_c...
# 2                                                    {}
# 3     {'review_scores_accuracy': 10, 'review_scores_...
# 4                                                    {}
# ...                                                 ...
# 5550  {'review_scores_accuracy': 10, 'review_scores_...
# 5551  {'review_scores_accuracy': 10, 'review_scores_...
# 5552  {'review_scores_accuracy': 10, 'review_scores_...
# 5553                                                 {}
# 5554                                                 {}
#
#                                                 reviews security_deposit  \
# 0     [{'_id': '56904633', 'date': 2015-12-19 05:00:...              NaN
# 1     [{'_id': '58663741', 'date': 2016-01-03 05:00:...           200.00
# 2                                                    []          4476.00
# 3     [{'_id': '61050713', 'date': 2016-01-31 05:00:...              NaN
# 4                                                    []              NaN
# ...                                                 ...              ...
# 5550  [{'_id': '68762225', 'date': 2016-04-06 04:00:...           200.00
# 5551  [{'_id': '105800033', 'date': 2016-10-02 04:00...          3000.00
# 5552  [{'_id': '61004608', 'date': 2016-01-30 05:00:...           100.00
# 5553                                                 []              NaN
# 5554                                                 []              NaN
#
#      cleaning_fee monthly_price reviews_per_month
# 0             NaN           NaN               NaN
# 1           35.00           NaN               NaN
# 2          112.00           NaN               NaN
# 3             NaN           NaN               NaN
# 4             NaN           NaN               NaN
# ...           ...           ...               ...
# 5550       315.00           NaN               NaN
# 5551          NaN           NaN               NaN
# 5552          NaN           NaN               NaN
# 5553          NaN           NaN               NaN
# 5554          NaN           NaN               NaN
#
# [5555 rows x 42 columns]

# %%
#Extracting data
Extracted_Data = []
for i in col.find():
    data = {
    "Id": i['_id'],
    "listing_url": i['listing_url'],
    "name": i['name'],
    "description": i['description'],
    "house_rules": i.get('house_rules'),  
    "property_type": i['property_type'],
    "room_type": i['room_type'],
    "bed_type": i['bed_type'],
    "minimum_nights": int(i['minimum_nights']),
    "maximum_nights": int(i['maximum_nights']),
    "cancellation_policy": i['cancellation_policy'],
    "accommodates": i['accommodates'],
    "bedrooms": i.get('bedrooms'),  
    "beds": i.get('beds'),
    "availability": i['availability']['availability_365'],
    "price": i['price'],
    "security_deposit": i.get('security_deposit'),  
    "cleaning_fee": i.get('cleaning_fee'),  
    "extra_people": i['extra_people'],
    "guests_included": i['guests_included'],
    "number_of_reviews": i['number_of_reviews'],
    "review_scores": i.get('review_scores'),  
    "amenities": i['amenities'],
    "host_name": i['host']['host_name'],
    "host_id": i['host']['host_id'],
    "street": i['address']['street'],
    "country": i['address']['country'],
    "country_code": i['address']['country_code'],
    "location_type": i['address']['location']['type'],
    "longitude": i['address']['location']['coordinates'][0],
    "latitude": i['address']['location']['coordinates'][1],
    "is_location_exact": i['address']['location']['is_location_exact']
    }
    Extracted_Data.append(data)

df1=pd.DataFrame(Extracted_Data)

#Changing datatype
df1.price = df1.price.astype(str).astype(float)
df1.security_deposit = df1.security_deposit[~df1.security_deposit.isna()].astype(str).astype(float)
df1.cleaning_fee = df1.cleaning_fee[~df1.cleaning_fee.isna()].astype(str).astype(float)
df1.extra_people = df1.extra_people.astype(str).astype(float)
df1.guests_included = df1.guests_included.astype(str).astype(float)
#Changing dtype for review score
# Assuming your DataFrame is named df
column_name = 'review_scores'
# Check if the specified column contains dictionaries
if isinstance(df1[column_name].iloc[0], dict):
    # Convert each dictionary into a tuple
    df1[column_name] = df1[column_name].apply(tuple)
# Assuming your DataFrame is named df
# First, let's clean up the review_scores column
# For example, if it contains non-integer values or missing values, you might do something like this:

# Replace any non-integer values with NaN
df1['review_scores'] = pd.to_numeric(df1['review_scores'], errors='coerce')

# Handle missing values (NaN) according to your preference, for example, by filling them with a specific value like 0:
df1['review_scores'].fillna(0, inplace=True)

# Now, convert the column to integer type
df1['review_scores'] = df1['review_scores'].astype(int)

#host_id
df1.host_id=df1.host_id.astype(str).astype(int)

df1.info()

#Finding Missing value
df1.isna().sum()

#Filling missing values
df1['beds']=df1['beds'].fillna(df1['beds'].median)
df1['bedrooms']=df1['bedrooms'].fillna(df1['bedrooms'].mode)
df1['security_deposit']=df1['security_deposit'].fillna(df1['security_deposit'].median)
df1['cleaning_fee']=df1['cleaning_fee'].fillna(df1['cleaning_fee'].median)

#Finding missing text data
import pandas as pd

# Assuming df1 is your DataFrame
# Check for empty spaces in the DataFrame
empty_spaces = df1.isin(['']).sum()

# Display columns with empty spaces
print(empty_spaces)

# Filling Empty values in Description and House rules columns
df1['description'].replace(to_replace='', value='No Description Provided', inplace=True)
df1['house_rules'].replace(to_replace='', value='No House rules Provided', inplace=True)
df1['name'].replace(to_replace='', value='Not Available', inplace=True)

#Finding missing text data
import pandas as pd

# Assuming df1 is your DataFrame
# Check for empty spaces in the DataFrame
empty_spaces = df1.isin(['']).sum()

# Display columns with empty spaces
print(empty_spaces)
#Checking size of df before duplicating
print(df1.shape)
# Iterate through each column in the DataFrame
for column in df1.columns:
    # Check if any element in the column is of type list
    if any(isinstance(item, list) for item in df1[column]):
        print(f"Column '{column}' contains lists.")
        
        # Convert lists to strings
        df1[column] = df1[column].apply(lambda x: ','.join(x) if isinstance(x, list) else x)
        print("Lists converted to strings")

# Now you can safely drop duplicates
df1 = df1.drop_duplicates()
print(df1.shape)
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13476\2426528158.py:63: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['review_scores'].fillna(0, inplace=True)
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13476\2426528158.py:93: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['description'].replace(to_replace='', value='No Description Provided', inplace=True)
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13476\2426528158.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['house_rules'].replace(to_replace='', value='No House rules Provided', inplace=True)
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13476\2426528158.py:95: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['name'].replace(to_replace='', value='Not Available', inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   description          5555 non-null   object
#  4   house_rules          5555 non-null   object
#  5   property_type        5555 non-null   object
#  6   room_type            5555 non-null   object
#  7   bed_type             5555 non-null   object
#  8   minimum_nights       5555 non-null   int64
#  9   maximum_nights       5555 non-null   int64
#  10  cancellation_policy  5555 non-null   object
#  11  accommodates         5555 non-null   int64
#  12  bedrooms             5550 non-null   float64
#  13  beds                 5542 non-null   float64
#  14  availability         5555 non-null   int64
#  15  price                5555 non-null   float64
#  16  security_deposit     3471 non-null   float64
#  17  cleaning_fee         4024 non-null   float64
#  18  extra_people         5555 non-null   float64
#  19  guests_included      5555 non-null   float64
#  20  number_of_reviews    5555 non-null   int64
#  21  review_scores        5555 non-null   int32
#  22  amenities            5555 non-null   object
#  23  host_name            5555 non-null   object
#  24  host_id              5555 non-null   int32
#  25  street               5555 non-null   object
#  26  country              5555 non-null   object
#  27  country_code         5555 non-null   object
#  28  location_type        5555 non-null   object
#  29  longitude            5555 non-null   float64
#  30  latitude             5555 non-null   float64
#  31  is_location_exact    5555 non-null   bool
# dtypes: bool(1), float64(9), int32(2), int64(5), object(15)
# memory usage: 1.3+ MB
# Id                        0
# listing_url               0
# name                      8
# description              95
# house_rules            2285
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  0
# beds                      0
# availability              0
# price                     0
# security_deposit          0
# cleaning_fee              0
# extra_people              0
# guests_included           0
# number_of_reviews         0
# review_scores             0
# amenities                 0
# host_name                 0
# host_id                   0
# street                    0
# country                   0
# country_code              0
# location_type             0
# longitude                 0
# latitude                  0
# is_location_exact         0
# dtype: int64
# Id                     0
# listing_url            0
# name                   0
# description            0
# house_rules            0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# availability           0
# price                  0
# security_deposit       0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# number_of_reviews      0
# review_scores          0
# amenities              0
# host_name              0
# host_id                0
# street                 0
# country                0
# country_code           0
# location_type          0
# longitude              0
# latitude               0
# is_location_exact      0
# dtype: int64
# (5555, 32)
# Column 'amenities' contains lists.
# Lists converted to strings
# (5555, 32)

# %%
df1
# Out:
#             Id                            listing_url  \
# 0     10059872  https://www.airbnb.com/rooms/10059872
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10069642  https://www.airbnb.com/rooms/10069642
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10066928  https://www.airbnb.com/rooms/10066928
# ...        ...                                    ...
# 5550   9993190   https://www.airbnb.com/rooms/9993190
# 5551   9887054   https://www.airbnb.com/rooms/9887054
# 5552   9937100   https://www.airbnb.com/rooms/9937100
# 5553   9908871   https://www.airbnb.com/rooms/9908871
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                    Soho Cozy, Spacious and Convenient
# 1                               Ribeira Charming Duplex
# 2                    Ótimo Apto proximo Parque Olimpico
# 3                              Private Room in Bushwick
# 4                        3 chambres au coeur du Plateau
# ...                                                 ...
# 5550  Just Steps from the Ocean at Premier Platinum ...
# 5551                Quarry Bay fully furnished studio C
# 5552                Frida's Centric&Stylish Studio Apt.
# 5553                        Family friendly beach house
# 5554                        Alugo Apartamento na Tijuca
#
#                                             description  \
# 0     Clean, fully furnish, Spacious 1 bedroom flat ...
# 1     Fantastic duplex apartment with three bedrooms...
# 2     Apartamento próximo ao centro dos Jogos Olímpi...
# 3     Here exists a very cozy room for rent in a sha...
# 4     Notre appartement comporte 3 chambres avec cha...
# ...                                                 ...
# 5550  Relax Hawaiian Style in Gated Community on Oce...
# 5551   Newly renovated studio flat with full furniture.
# 5552  Unique loft apartment with a Frida Kahlo decor...
# 5553  Only 400 metres to the beach,2 x carparks,clos...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                             house_rules property_type  \
# 0                               No House rules Provided     Apartment
# 1                           Make the house your home...         House
# 2                               No House rules Provided     Apartment
# 3                               No House rules Provided     Apartment
# 4                    Merci de respecter ce lieu de vie.     Apartment
# ...                                                 ...           ...
# 5550  As a guest of Coconut Condos, I agree to the f...     Townhouse
# 5551                            No House rules Provided     Apartment
# 5552  Our standard check-in time is from 2 pm but we...          Loft
# 5553                            No House rules Provided         House
# 5554  Cuidar das instalações e objetos da casa em pe...     Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  ...  \
# 0     Entire home/apt  Real Bed               4              20  ...
# 1     Entire home/apt  Real Bed               2              30  ...
# 2     Entire home/apt  Real Bed              15              20  ...
# 3        Private room  Real Bed              14            1125  ...
# 4     Entire home/apt  Real Bed               1            1125  ...
# ...               ...       ...             ...             ...  ...
# 5550  Entire home/apt  Real Bed               3             365  ...
# 5551     Private room  Real Bed               3            1125  ...
# 5552  Entire home/apt  Real Bed              31             365  ...
# 5553  Entire home/apt  Real Bed               1            1125  ...
# 5554  Entire home/apt  Real Bed               1            1125  ...
#
#                                               amenities       host_name  \
# 0     Air conditioning,Kitchen,Smoking allowed,Doorm...        Giovanni
# 1     TV,Cable TV,Wifi,Kitchen,Paid parking off prem...     Ana&Gonçalo
# 2     TV,Cable TV,Internet,Wifi,Air conditioning,Whe...        Jonathan
# 3     Internet,Wifi,Air conditioning,Kitchen,Buzzer/...            Josh
# 4     Internet,Wifi,Kitchen,Heating,Family/kid frien...         Margaux
# ...                                                 ...             ...
# 5550  TV,Wifi,Air conditioning,Pool,Kitchen,Free par...  Coconut Condos
# 5551  TV,Wifi,Air conditioning,Kitchen,Elevator,Hot ...             Cat
# 5552  Internet,Wifi,Air conditioning,Kitchen,Paid pa...       Ewa & Pau
# 5553  TV,Cable TV,Kitchen,Free parking on premises,F...           Craig
# 5554  TV,Cable TV,Internet,Wifi,Air conditioning,Kit...          Aliane
#
#        host_id                                  street        country  \
# 0     51624384  Hong Kong, Hong Kong Island, Hong Kong      Hong Kong
# 1     51399391                  Porto, Porto, Portugal       Portugal
# 2     51670240  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil
# 3     11275734             Brooklyn, NY, United States  United States
# 4      9036477                Montréal, Québec, Canada         Canada
# ...        ...                                     ...            ...
# 5550  51013381              Lahaina, HI, United States  United States
# 5551  31386255  Hong Kong, Hong Kong Island, Hong Kong      Hong Kong
# 5552   3479346             Barcelona, Catalunya, Spain          Spain
# 5553  20914019             North Bondi, NSW, Australia      Australia
# 5554  47092481  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil
#
#       country_code location_type   longitude   latitude  is_location_exact
# 0               HK         Point  114.150270  22.281580               True
# 1               PT         Point   -8.613080  41.141300              False
# 2               BR         Point  -43.431112 -23.000358              False
# 3               US         Point  -73.936150  40.697910               True
# 4               CA         Point  -73.573830  45.522330               True
# ...            ...           ...         ...        ...                ...
# 5550            US         Point -156.667520  20.858940              False
# 5551            HK         Point  114.207220  22.291570              False
# 5552            ES         Point    2.173040  41.387790              False
# 5553            AU         Point  151.282410 -33.888180               True
# 5554            BR         Point  -43.173761 -22.908336              False
#
# [5555 rows x 32 columns]

# %%
df1.to_csv("Airbnb.csv",index=False)

# %%
df1['guests_included']
# Out:
# 0       1.0
# 1       6.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 5550    1.0
# 5551    2.0
# 5552    1.0
# 5553    1.0
# 5554    1.0
# Name: guests_included, Length: 5555, dtype: float64

# %%
#Converting it to excel for tableau 
df1.to_json('C:/Users/Welcome/OneDrive/Desktop/Airbnb/Airbnb.excel')
